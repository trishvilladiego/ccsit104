# %% [markdown]
# # **Assessment Task 5**

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # 1. Data Preprocessing

# %%
# Load the dataset into a Pandas DataFrame
df = pd.read_csv('BankCustomerData.csv')

# Convert categorical variables into dummy variables
df_dummies = pd.get_dummies(df["loan"])

# Convert the target variable subscribed into binary format
df['subscribed'] = df['loan'].map({'yes': 1, 'no': 0})

# %% [markdown]
# # 2. Feature Selection

# %%
x = df.drop(['default','housing','loan','term_deposit'], axis=1)
y = df['subscribed']

# %% [markdown]
# # 3. Data Splitting

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# # 4. Model Training

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_encoded)
X_test_scaled = scaler.transform(X_test_encoded)

model = LogisticRegression()
model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # 5. Model Evaluation

# %%
y_pred = model.predict(X_test_scaled)

# %% [markdown]
# # 6. Conclusion

# %%
accuracy = accuracy_score(y_test,y_pred)
conf_matrix = confusion_matrix(y_test,y_pred)
class_report = classification_report(y_test,y_pred)

print(f"Accuracy: {accuracy}")
print("Confusion Matrix: ")
print(conf_matrix)
print("Classification Report: ")
print(class_report)
# Out:
# Accuracy: 1.0
# Confusion Matrix:
# [[7158    0]
#  [   0 1370]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7158
#            1       1.00      1.00      1.00      1370
#
#     accuracy                           1.00      8528
#    macro avg       1.00      1.00      1.00      8528
# weighted avg       1.00      1.00      1.00      8528
